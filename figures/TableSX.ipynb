# %%
import scipy.stats
import numpy as np
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.sandbox.stats.multicomp import get_tukey_pvalue
import joblib
import pandas as pd

# %%
decoding_results=pd.read_hdf('../data/Figure5Revision.h5', data='key')

# %%
def get_data(decoding_results, task, decoders, methods, window, modality, num_neurons):
    if modality == 'ca':
        index = 0
    elif modality == 'np':
        index = 1
    accs=[]
    keys=[]
    for decoder, method in zip(decoders,methods):
        key = f'{modality}_{method}_{window}'
        if 'joint' in method:
            seeds = decoding_results[task][decoder][key][num_neurons]
            acc= [abs(s[index]).mean() for s in seeds]
        else:
            acc= abs(np.array(decoding_results[task][decoder][key][num_neurons])).mean(axis=-1)
        accs.append(acc)
        keys.append([f'{key}_{decoder}']*len(acc))
    return np.concatenate(accs),np.concatenate(keys)

    
def concat_neurons(decoding_results, task, decoder, method, window, modality):
    if modality == 'ca':
        index = 0
    elif modality == 'np':
        index = 1
    key = f'{modality}_{method}_{window}'
    accs=[]
    for n in decoding_results[task][decoder][key].keys():
        if 'joint' in method:
            seeds = decoding_results[task][decoder][key][n]
            accs.append([abs(s[index]).mean() for s in seeds])
        else:
            accs.append(abs(np.array(decoding_results[task][decoder][key][n])).mean(axis=-1))
    return np.concatenate(accs)

# %% [markdown]
# ## ANOVA for CEBRA, CEBRA-joint, baseline 330 ms (10 frame window):

# %%
np_total_stats = scipy.stats.f_oneway(concat_neurons(decoding_results, 'frame_err', 'knn', 'cebra', '330', 'np'), 
                                      concat_neurons(decoding_results, 'frame_err', 'knn', 'cebra_joint', '330', 'np'), 
                                      concat_neurons(decoding_results, 'frame_err', 'knn', 'baseline', '330', 'np'),
                                     concat_neurons(decoding_results, 'frame_err', 'bayes', 'baseline', '330', 'np'))



print(f'NP total stats \n {np_total_stats}')
# Out:
# NP total stats
#  F_onewayResult(statistic=0.5478740874841249, pvalue=0.6501446364163558)

# %% [markdown]
# ## ANOVA for CEBRA, CEBRA-joint, baseline 33 ms (1 frame window):

# %%
np_total_stats = scipy.stats.f_oneway(concat_neurons(decoding_results, 'frame_err', 'knn', 'cebra', '33', 'np'), 
                                      concat_neurons(decoding_results, 'frame_err', 'knn', 'cebra_joint', '33', 'np'), 
                                      concat_neurons(decoding_results, 'frame_err', 'knn', 'baseline', '33', 'np'),
                                     concat_neurons(decoding_results, 'frame_err', 'bayes', 'baseline', '33', 'np'))



print(f'NP total stats \n {np_total_stats}')
# Out:
# NP total stats
#  F_onewayResult(statistic=7.255789505462228, pvalue=0.00012189571069103389)

# %% [markdown]
# ## ANOVA for CEBRA, CEBRA-joint, baseline for each neuron numbers

# %%
num_neurons = [10, 30, 50, 100, 200, 400, 600, 800, 900, 1000]
for i in num_neurons:
    print(f'For {i} neurons from np recording (330ms):')
    
    np_data, np_keys = get_data(decoding_results, 'frame_err', ['knn', 'knn', 'knn', 'bayes'], ['cebra', 'cebra_joint', 'baseline', 'baseline'], '330', 'np', i)
    
    stats=pairwise_tukeyhsd(np_data.flatten(), np_keys,)
    print(stats)
# Out:
# For 10 neurons from np recording (330ms):
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================================
#         group1                group2         meandiff p-adj   lower    upper  reject
# ------------------------------------------------------------------------------------
# np_baseline_330_bayes    np_baseline_330_knn  30.3086 0.1054  -4.9411 65.5583  False
# np_baseline_330_bayes       np_cebra_330_knn  25.0236 0.2179 -10.2261 60.2733  False
# np_baseline_330_bayes np_cebra_joint_330_knn  46.3276 0.0083  11.0779 81.5773   True
#   np_baseline_330_knn       np_cebra_330_knn   -5.285 0.9726 -40.5347 29.9647  False
#   np_baseline_330_knn np_cebra_joint_330_knn   16.019 0.5759 -19.2307 51.2687  False
#      np_cebra_330_knn np_cebra_joint_330_knn   21.304 0.3417 -13.9457 56.5537  False
# ------------------------------------------------------------------------------------
# For 30 neurons from np recording (330ms):
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================================
#         group1                group2         meandiff p-adj   lower    upper  reject
# ------------------------------------------------------------------------------------
# np_baseline_330_bayes    np_baseline_330_knn  42.7574 0.0932  -5.6365 91.1513  False
# np_baseline_330_bayes       np_cebra_330_knn   25.194 0.4662 -23.1999 73.5879  False
# np_baseline_330_bayes np_cebra_joint_330_knn  43.0488 0.0904  -5.3451 91.4427  False
#   np_baseline_330_knn       np_cebra_330_knn -17.5634 0.7301 -65.9573 30.8305  False
#   np_baseline_330_knn np_cebra_joint_330_knn   0.2914    1.0 -48.1025 48.6853  False
#      np_cebra_330_knn np_cebra_joint_330_knn  17.8548 0.7203 -30.5391 66.2487  False
# ------------------------------------------------------------------------------------
# For 50 neurons from np recording (330ms):
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================================
#         group1                group2         meandiff p-adj   lower    upper  reject
# ------------------------------------------------------------------------------------
# np_baseline_330_bayes    np_baseline_330_knn  36.0349 0.3376 -23.2912 95.3611  False
# np_baseline_330_bayes       np_cebra_330_knn  12.0902 0.9357 -47.2359 71.4163  False
# np_baseline_330_bayes np_cebra_joint_330_knn  12.9926  0.922 -46.3336 72.3187  False
#   np_baseline_330_knn       np_cebra_330_knn -23.9447 0.6625 -83.2708 35.3814  False
#   np_baseline_330_knn np_cebra_joint_330_knn -23.0424  0.688 -82.3685 36.2837  False
#      np_cebra_330_knn np_cebra_joint_330_knn   0.9023    1.0 -58.4238 60.2284  False
# ------------------------------------------------------------------------------------
# For 100 neurons from np recording (330ms):
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================================
#         group1                group2         meandiff p-adj   lower    upper  reject
# ------------------------------------------------------------------------------------
# np_baseline_330_bayes    np_baseline_330_knn  31.5343  0.009   7.3031 55.7654   True
# np_baseline_330_bayes       np_cebra_330_knn   8.0164 0.7807 -16.2147 32.2476  False
# np_baseline_330_bayes np_cebra_joint_330_knn   3.7558 0.9699 -20.4753  27.987  False
#   np_baseline_330_knn       np_cebra_330_knn -23.5178 0.0587  -47.749  0.7133  False
#   np_baseline_330_knn np_cebra_joint_330_knn -27.7784  0.022 -52.0096 -3.5473   True
#      np_cebra_330_knn np_cebra_joint_330_knn  -4.2606 0.9572 -28.4918 19.9706  False
# ------------------------------------------------------------------------------------
# For 200 neurons from np recording (330ms):
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================================
#         group1                group2         meandiff p-adj   lower    upper  reject
# ------------------------------------------------------------------------------------
# np_baseline_330_bayes    np_baseline_330_knn  17.4511 0.0056   4.8231  30.079   True
# np_baseline_330_bayes       np_cebra_330_knn  -4.6911 0.7161 -17.3191  7.9368  False
# np_baseline_330_bayes np_cebra_joint_330_knn  -0.0216    1.0 -12.6496 12.6063  False
#   np_baseline_330_knn       np_cebra_330_knn -22.1422 0.0007 -34.7701 -9.5142   True
#   np_baseline_330_knn np_cebra_joint_330_knn -17.4727 0.0056 -30.1006 -4.8447   True
#      np_cebra_330_knn np_cebra_joint_330_knn   4.6695 0.7189  -7.9585 17.2975  False
# ------------------------------------------------------------------------------------
# For 400 neurons from np recording (330ms):
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================================
#         group1                group2         meandiff p-adj   lower    upper  reject
# ------------------------------------------------------------------------------------
# np_baseline_330_bayes    np_baseline_330_knn   5.5827 0.4589   -5.048 16.2134  False
# np_baseline_330_bayes       np_cebra_330_knn  -5.5064 0.4704 -16.1371  5.1243  False
# np_baseline_330_bayes np_cebra_joint_330_knn  -7.4924  0.223 -18.1231  3.1382  False
#   np_baseline_330_knn       np_cebra_330_knn -11.0891 0.0394 -21.7197 -0.4584   True
#   np_baseline_330_knn np_cebra_joint_330_knn -13.0751 0.0136 -23.7058 -2.4444   True
#      np_cebra_330_knn np_cebra_joint_330_knn  -1.9861 0.9493 -12.6167  8.6446  False
# ------------------------------------------------------------------------------------
# For 600 neurons from np recording (330ms):
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================================
#         group1                group2         meandiff p-adj   lower    upper  reject
# ------------------------------------------------------------------------------------
# np_baseline_330_bayes    np_baseline_330_knn   7.7031 0.0176   1.2069 14.1993   True
# np_baseline_330_bayes       np_cebra_330_knn  -4.7063 0.2039 -11.2025  1.7899  False
# np_baseline_330_bayes np_cebra_joint_330_knn  -3.1244 0.5311  -9.6206  3.3718  False
#   np_baseline_330_knn       np_cebra_330_knn -12.4094 0.0003 -18.9056 -5.9132   True
#   np_baseline_330_knn np_cebra_joint_330_knn -10.8276 0.0011 -17.3238 -4.3314   True
#      np_cebra_330_knn np_cebra_joint_330_knn   1.5819 0.8969  -4.9143  8.0781  False
# ------------------------------------------------------------------------------------
# For 800 neurons from np recording (330ms):
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================================
#         group1                group2         meandiff p-adj   lower    upper  reject
# ------------------------------------------------------------------------------------
# np_baseline_330_bayes    np_baseline_330_knn   4.9577 0.1283  -1.0816  10.997  False
# np_baseline_330_bayes       np_cebra_330_knn  -4.5815 0.1738 -10.6208  1.4578  False
# np_baseline_330_bayes np_cebra_joint_330_knn  -5.4724 0.0828 -11.5118  0.5669  False
#   np_baseline_330_knn       np_cebra_330_knn  -9.5392 0.0018 -15.5785 -3.4999   True
#   np_baseline_330_knn np_cebra_joint_330_knn -10.4302 0.0008 -16.4695 -4.3909   True
#      np_cebra_330_knn np_cebra_joint_330_knn  -0.8909 0.9739  -6.9303  5.1484  False
# ------------------------------------------------------------------------------------
# For 900 neurons from np recording (330ms):
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================================
#         group1                group2         meandiff p-adj   lower    upper  reject
# ------------------------------------------------------------------------------------
# np_baseline_330_bayes    np_baseline_330_knn   3.5597 0.2336  -1.5659  8.6852  False
# np_baseline_330_bayes       np_cebra_330_knn  -6.9454 0.0066  -12.071 -1.8199   True
# np_baseline_330_bayes np_cebra_joint_330_knn  -6.7757  0.008 -11.9012 -1.6501   True
#   np_baseline_330_knn       np_cebra_330_knn -10.5051 0.0001 -15.6307 -5.3795   True
#   np_baseline_330_knn np_cebra_joint_330_knn -10.3353 0.0002 -15.4609 -5.2098   True
#      np_cebra_330_knn np_cebra_joint_330_knn   0.1698 0.9997  -4.9558  5.2953  False
# ------------------------------------------------------------------------------------
# For 1000 neurons from np recording (330ms):
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================================
#         group1                group2         meandiff p-adj   lower    upper  reject
# ------------------------------------------------------------------------------------
# np_baseline_330_bayes    np_baseline_330_knn   1.8628 0.5277  -1.9939  5.7195  False
# np_baseline_330_bayes       np_cebra_330_knn  -6.3068 0.0013 -10.1635 -2.4501   True
# np_baseline_330_bayes np_cebra_joint_330_knn  -6.4403 0.0011  -10.297 -2.5836   True
#   np_baseline_330_knn       np_cebra_330_knn  -8.1696 0.0001 -12.0263 -4.3129   True
#   np_baseline_330_knn np_cebra_joint_330_knn  -8.3031 0.0001 -12.1597 -4.4464   True
#      np_cebra_330_knn np_cebra_joint_330_knn  -0.1334 0.9996  -3.9901  3.7232  False
# ------------------------------------------------------------------------------------

# %%
num_neurons = [10, 30, 50, 100, 200, 400, 600, 800, 900, 1000]
for i in num_neurons:
    print(f'For {i} neurons from np recording (33ms):')
    
    np_data, np_keys = get_data(decoding_results, 'frame_err', ['knn', 'knn', 'knn', 'bayes'], ['cebra', 'cebra_joint', 'baseline', 'baseline'], '33', 'np', i)
    
    stats=pairwise_tukeyhsd(np_data.flatten(), np_keys)
    print(stats)
# Out:
# For 10 neurons from np recording (33ms):
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================================
#        group1                group2        meandiff p-adj   lower    upper   reject
# -----------------------------------------------------------------------------------
# np_baseline_33_bayes    np_baseline_33_knn  46.1798 0.0064  12.2479  80.1117   True
# np_baseline_33_bayes       np_cebra_33_knn  -1.9331 0.9984  -35.865  31.9988  False
# np_baseline_33_bayes np_cebra_joint_33_knn    -3.71  0.989 -37.6419  30.2219  False
#   np_baseline_33_knn       np_cebra_33_knn -48.1129 0.0046 -82.0448  -14.181   True
#   np_baseline_33_knn np_cebra_joint_33_knn -49.8898 0.0034 -83.8217 -15.9579   True
#      np_cebra_33_knn np_cebra_joint_33_knn  -1.7769 0.9987 -35.7088   32.155  False
# -----------------------------------------------------------------------------------
# For 30 neurons from np recording (33ms):
#                Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================================
#        group1                group2        meandiff p-adj   lower    upper  reject
# ----------------------------------------------------------------------------------
# np_baseline_33_bayes    np_baseline_33_knn   22.018 0.2562 -10.6734 54.7094  False
# np_baseline_33_bayes       np_cebra_33_knn  -0.7053 0.9999 -33.3967 31.9861  False
# np_baseline_33_bayes np_cebra_joint_33_knn  -1.6238 0.9989 -34.3152 31.0676  False
#   np_baseline_33_knn       np_cebra_33_knn -22.7233 0.2329 -55.4147  9.9681  False
#   np_baseline_33_knn np_cebra_joint_33_knn -23.6418 0.2051 -56.3332  9.0496  False
#      np_cebra_33_knn np_cebra_joint_33_knn  -0.9184 0.9998 -33.6098 31.7729  False
# ----------------------------------------------------------------------------------
# For 50 neurons from np recording (33ms):
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================================
#        group1                group2        meandiff p-adj   lower    upper   reject
# -----------------------------------------------------------------------------------
# np_baseline_33_bayes    np_baseline_33_knn    23.97  0.128  -5.2125  53.1525  False
# np_baseline_33_bayes       np_cebra_33_knn  -24.378 0.1193 -53.5605   4.8045  False
# np_baseline_33_bayes np_cebra_joint_33_knn -17.9856 0.3257  -47.168  11.1969  False
#   np_baseline_33_knn       np_cebra_33_knn  -48.348 0.0011 -77.5305 -19.1655   True
#   np_baseline_33_knn np_cebra_joint_33_knn -41.9556 0.0041  -71.138 -12.7731   True
#      np_cebra_33_knn np_cebra_joint_33_knn   6.3924  0.922   -22.79  35.5749  False
# -----------------------------------------------------------------------------------
# For 100 neurons from np recording (33ms):
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================================
#        group1                group2        meandiff p-adj   lower    upper   reject
# -----------------------------------------------------------------------------------
# np_baseline_33_bayes    np_baseline_33_knn  41.9933 0.0013  16.2206   67.766   True
# np_baseline_33_bayes       np_cebra_33_knn  -2.9507 0.9874 -28.7234   22.822  False
# np_baseline_33_bayes np_cebra_joint_33_knn -29.1811 0.0238 -54.9538  -3.4084   True
#   np_baseline_33_knn       np_cebra_33_knn  -44.944 0.0007 -70.7167 -19.1713   True
#   np_baseline_33_knn np_cebra_joint_33_knn -71.1744    0.0 -96.9471 -45.4018   True
#      np_cebra_33_knn np_cebra_joint_33_knn -26.2304 0.0453 -52.0031  -0.4578   True
# -----------------------------------------------------------------------------------
# For 200 neurons from np recording (33ms):
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================================
#        group1                group2        meandiff p-adj    lower    upper   reject
# ------------------------------------------------------------------------------------
# np_baseline_33_bayes    np_baseline_33_knn  34.9604 0.0014    13.436  56.4848   True
# np_baseline_33_bayes       np_cebra_33_knn -53.5842    0.0  -75.1086 -32.0598   True
# np_baseline_33_bayes np_cebra_joint_33_knn -59.6476    0.0   -81.172 -38.1232   True
#   np_baseline_33_knn       np_cebra_33_knn -88.5447    0.0 -110.0691 -67.0203   True
#   np_baseline_33_knn np_cebra_joint_33_knn  -94.608    0.0 -116.1324 -73.0836   True
#      np_cebra_33_knn np_cebra_joint_33_knn  -6.0633 0.8507  -27.5877  15.4611  False
# ------------------------------------------------------------------------------------
# For 400 neurons from np recording (33ms):
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================================
#        group1                group2        meandiff p-adj    lower    upper   reject
# ------------------------------------------------------------------------------------
# np_baseline_33_bayes    np_baseline_33_knn  10.1469 0.1316     -2.29  22.5838  False
# np_baseline_33_bayes       np_cebra_33_knn -63.1696    0.0  -75.6064 -50.7327   True
# np_baseline_33_bayes np_cebra_joint_33_knn -81.4789    0.0  -93.9158  -69.042   True
#   np_baseline_33_knn       np_cebra_33_knn -73.3164    0.0  -85.7533 -60.8796   True
#   np_baseline_33_knn np_cebra_joint_33_knn -91.6258    0.0 -104.0627 -79.1889   True
#      np_cebra_33_knn np_cebra_joint_33_knn -18.3093 0.0033  -30.7462  -5.8725   True
# ------------------------------------------------------------------------------------
# For 600 neurons from np recording (33ms):
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================================
#        group1                group2        meandiff p-adj    lower    upper   reject
# ------------------------------------------------------------------------------------
# np_baseline_33_bayes    np_baseline_33_knn  11.0296 0.2977    -6.251  28.3101  False
# np_baseline_33_bayes       np_cebra_33_knn -52.7204    0.0   -70.001 -35.4399   True
# np_baseline_33_bayes np_cebra_joint_33_knn -77.7331    0.0  -95.0136 -60.4526   True
#   np_baseline_33_knn       np_cebra_33_knn   -63.75    0.0  -81.0305 -46.4695   True
#   np_baseline_33_knn np_cebra_joint_33_knn -88.7627    0.0 -106.0432 -71.4822   True
#      np_cebra_33_knn np_cebra_joint_33_knn -25.0127 0.0038  -42.2932  -7.7322   True
# ------------------------------------------------------------------------------------
# For 800 neurons from np recording (33ms):
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================================
#        group1                group2        meandiff p-adj    lower    upper   reject
# ------------------------------------------------------------------------------------
# np_baseline_33_bayes    np_baseline_33_knn  18.6067  0.021    2.4951  34.7182   True
# np_baseline_33_bayes       np_cebra_33_knn   -45.42    0.0  -61.5316 -29.3084   True
# np_baseline_33_bayes np_cebra_joint_33_knn -68.4347    0.0  -84.5462 -52.3231   True
#   np_baseline_33_knn       np_cebra_33_knn -64.0267    0.0  -80.1382 -47.9151   True
#   np_baseline_33_knn np_cebra_joint_33_knn -87.0413    0.0 -103.1529 -70.9298   True
#      np_cebra_33_knn np_cebra_joint_33_knn -23.0147 0.0043  -39.1262  -6.9031   True
# ------------------------------------------------------------------------------------
# For 900 neurons from np recording (33ms):
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================================
#        group1                group2        meandiff p-adj    lower    upper   reject
# ------------------------------------------------------------------------------------
# np_baseline_33_bayes    np_baseline_33_knn  25.3476 0.0036    7.9806  42.7145   True
# np_baseline_33_bayes       np_cebra_33_knn -39.7816    0.0  -57.1485 -22.4146   True
# np_baseline_33_bayes np_cebra_joint_33_knn -60.3056    0.0  -77.6725 -42.9386   True
#   np_baseline_33_knn       np_cebra_33_knn -65.1291    0.0  -82.4961 -47.7621   True
#   np_baseline_33_knn np_cebra_joint_33_knn -85.6531    0.0 -103.0201 -68.2861   True
#      np_cebra_33_knn np_cebra_joint_33_knn  -20.524  0.018   -37.891   -3.157   True
# ------------------------------------------------------------------------------------
# For 1000 neurons from np recording (33ms):
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================================
#        group1                group2        meandiff p-adj   lower    upper   reject
# -----------------------------------------------------------------------------------
# np_baseline_33_bayes    np_baseline_33_knn  22.5131 0.0006   9.8963  35.1299   True
# np_baseline_33_bayes       np_cebra_33_knn -48.7858    0.0 -61.4026  -36.169   True
# np_baseline_33_bayes np_cebra_joint_33_knn -57.2296    0.0 -69.8464 -44.6127   True
#   np_baseline_33_knn       np_cebra_33_knn -71.2989    0.0 -83.9157 -58.6821   True
#   np_baseline_33_knn np_cebra_joint_33_knn -79.7427    0.0 -92.3595 -67.1258   True
#      np_cebra_33_knn np_cebra_joint_33_knn  -8.4438  0.261 -21.0606    4.173  False
# -----------------------------------------------------------------------------------
